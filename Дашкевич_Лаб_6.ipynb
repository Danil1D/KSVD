# %% [markdown]
# <a href="https://colab.research.google.com/github/Danil1D/KSVD/blob/main/%D0%94%D0%B0%D1%88%D0%BA%D0%B5%D0%B2%D0%B8%D1%87_%D0%9B%D0%B0%D0%B1_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub ultralytics

import kagglehub
import os
from ultralytics import YOLO
import matplotlib.pyplot as plt

dataset_path = kagglehub.dataset_download('shlokraval/ppe-dataset-yolov8')

print("Файли у датасеті:")
print(os.listdir(dataset_path))

model = YOLO('yolov8n.pt')
yaml_path = os.path.join(dataset_path, 'data.yaml')

model.train(
    data=yaml_path,
    epochs=5,
    imgsz=320,
    batch=32,
    device=0,
    project='ppe_detection_colab',
    name='yolov8n_experiment'
)

results_path = '/content/ppe_detection_colab/yolov8n_experiment/results.png'

if os.path.exists(results_path):
    img = plt.imread(results_path)
    plt.figure(figsize=(10,6))
    plt.imshow(img)
    plt.axis('off')
    plt.title('Криві навчання (Loss, mAP, Precision, Recall)')
    plt.show()
else:
    print("Файл results.png не знайдено.")

metrics = model.val()

print("\n📊 Оцінка моделі:")
print(f"Mean Precision: {metrics.box.p.mean():.4f}")
print(f"Mean Recall: {metrics.box.r.mean():.4f}")
print(f"mAP@0.5: {metrics.box.map50:.4f}")
print(f"mAP@0.5-0.95: {metrics.box.map:.4f}")


model.predict(
    source=os.path.join(dataset_path, 'valid', 'images'),
    save=True,
    imgsz=320,
    conf=0.25,
    stream=True
)
# Out:
# ...
# Файли у датасеті:
# ['README.dataset.txt', 'README.roboflow.txt', 'data.yaml', 'valid', 'test', 'train']
# Ultralytics 8.3.119 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
